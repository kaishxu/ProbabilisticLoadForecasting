# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
# %matplotlib inline

# %%
data_set = 'Irish_2010'
df = pd.read_csv('../data/weather/weather_' + data_set + '_cleaned.csv')
weather = df['T'].values
plt.xlim(0, 17519)
plt.plot(weather)

# %%
data_set = 'London_2013'
df = pd.read_csv('../data/weather/weather_' + data_set + '_cleaned.csv')
weather = df['T'].values
plt.xlim(0, 17519)
plt.plot(weather)
